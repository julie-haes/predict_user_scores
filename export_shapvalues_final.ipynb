# %% [markdown]
# # LOAD IMPORTS

# %%
import re
import shap
import random
import string
import pickle
import pandas as pd
from scipy import sparse

import nltk
from nltk.corpus import stopwords 
nltk.download("stopwords")  
nltk.download('punkt')
nltk.download('wordnet')     
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package stopwords to C:\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # LOAD HELPERS

# %%
def parse_single_input(description):
        description = re.sub("[^a-zA-Z]"," ",description)
        description = description.lower()   
        description = nltk.word_tokenize(description)
        lemma = nltk.WordNetLemmatizer()
        description = [ lemma.lemmatize(word) for word in description]
        description = " ".join(description)
        return description

# %%
vectorizer = pickle.load(open('vectorizer.pk', 'rb'))

# %%
model = pickle.load(open('prediction_model.sav', 'rb'))

# %%
x_train = sparse.load_npz("x_train.npz")

# %% [markdown]
# # LOAD FILE

# %%
file = pd.read_csv('fitbit(30).csv', sep='\t', encoding = 'utf-8')
file
# Out:
#                  Name                                             Title  \
# 0     Amazon Customer                              Not worth the hassle
# 1              Aubrey                        Listen to the poor reviews
# 2     Amazon Customer                 It stopped working after 3 months
# 3              Sophia                      scratched and not that great
# 4   Cassandra Reising                           All in all a good watch
# 5            Gearhead                                Works as designed.
# 6          speedemonj                                 Great for fitness
# 7               Tyler                           Good bang for your buck
# 8     Kindle Customer      HUGE improvement over the first Fitbit Versa
# 9      Nicole Quigley                                         Love It!!
# 10    Amazon Customer                                Versa 2 is amazing
# 11                Hal                                   Simple and nice
# 12            Heather                                   Great purchase!
# 13   jessica albrecht                               I LOVE THE VERSA 2.
# 14             K Olds           Happy with the change to Fitbit Versa 2
# 15            Nkie715                               This watch, bad app
# 16       Eileen Jones                  Quality product for a good price
# 17     Skye Musacchia                                           Amazing
# 18            J. Wong      Sleep and weight tracking features are great
# 19      Phillip Ezell          Great capability for a reasonable price.
# 20             Debbie                                        I love it!
# 21       Dreamersland                                  Love my Fitbit!!
# 22       Katzapainter  Lots of info on this watch and very light weight
# 23        Ashlyn Pond         Comfy and motivational! Highly recommend!
# 24    Sierra Wrathall                                       Best watch!
# 25       Taylor Meeks                             The Best FitBit Ever!
# 26              Pappy                                    My New Fitbit.
# 27        Jill Fowler                               Happy with purchase
# 28               BevD               Absolutely love the Fitbit Versa 2!
# 29         UberFoodie                                   Love this thing
#
#                                                Review  Rating  Prediction
# 0   The strap is really hard to change. I managed ...     1.0    0.526897
# 1   I've used fitbit products for years. My well l...     1.0    0.687864
# 2   My fitbit stopped working after 3 months. The ...     2.0    2.005359
# 3   I have had this watch for less than a month an...     3.0    3.050132
# 4   I have had this for about a month and am very ...     4.0    3.999938
# 5   Bought this for my girlfriend. Thought I was t...     4.0    4.057881
# 6   Great for fitness, sleep, etc but you have to ...     4.0    4.112775
# 7   I had a Fitbit blaze before I got the versa 2 ...     4.0    4.344578
# 8   My first Fitbit Versa was great and died 4 mon...     5.0    4.502670
# 9   After buying a cheaper type of fitness tracker...     5.0    4.955996
# 10  Amazing sleep tracking and great step and hear...     5.0    4.512607
# 11  It’s pretty sleek. Sleep tracking doesn’t alwa...     5.0    5.020646
# 12  Very impressed with the features and comfort o...     5.0    5.031151
# 13  I love it! It's cute, comfortable, and works r...     5.0    5.043513
# 14  LOVE my new Fitbit Versa 2 Easy to learn and v...     5.0    5.054810
# 15  This watch is great, however, the Fitbit app k...     5.0    5.055352
# 16  I bought this item fairly quickly and without ...     5.0    5.056388
# 17  Absolutely love this watch!!!  I would highly ...     5.0    5.058111
# 18  I am mainly writing a review of the sleep and ...     5.0    5.060681
# 19  I like the fitness and sleep tracking capabili...     5.0    5.075542
# 20  I love my Versa 2, but I can only compare it t...     5.0    5.077276
# 21  Got it yesterday.  Super easy to set up, very ...     5.0    5.079998
# 22  Love my Fitbit. Very light weight. Everything ...     5.0    5.112900
# 23  I love my watch so much, and didn’t realize ho...     5.0    5.110651
# 24  Amazing smart watch/ fitness tracker! Well wor...     5.0    5.084164
# 25  What an awesome product!! I upgraded from the ...     5.0    5.138477
# 26  I have had several different Fitbit watches ov...     5.0    5.489931
# 27  Happy with purchase.  Love having the insight ...     5.0    5.402453
# 28  I purchased the Fitbit Versa 2 and I love it. ...     5.0    5.206577
# 29  I opted for this over an Apple Watch, because ...     5.0    5.170615

# %% [markdown]
# # LOOP OVER RECORDS

# %%
def predictRecord(record):
    input_score = int(record.Rating)
    input_review = record.Review
    
    new_x = parse_single_input(input_review)
    new_y = input_score
    
    input_array = []
    input_array.append(new_x)
    new_result = vectorizer.transform(input_array)
    new_prediction = model.predict(new_result)
    
    explainer = shap.LinearExplainer(model, x_train, feature_perturbation="interventional")
    shap_values = explainer.shap_values(new_result)
    
    df_shap = pd.DataFrame({'shap': explainer.shap_values(new_result)[0], 'term': vectorizer.get_feature_names(), 'occurrence': new_result.toarray()[0]})
        
    return df_shap

# %%
def getSHAPValues(df_shap):
    df_shap_lower = df_shap.sort_values(by=['shap'],ascending=True).head(20)
    df_shap_higher = df_shap.sort_values(by=['shap'],ascending=False).head(20)
    df_result = pd.concat([df_shap_higher, df_shap_lower])
    df_result['orientation'] = ["negative" if x < 0 else "positive" for x in df_result['shap']]   
    
    # Sort in order of summary plot
    n = df_result.reindex(df_result.shap.abs().sort_values(ascending=False).index)
    return n.head(20)

# %%
def getFactor(shapvalue, occurrence):
    factor = shapvalue
    if (occurrence > 1):
        factor = factor / occurrence
        
    return round(abs(factor),2)

# %%
def createTermID(term, shap):
    k = str(abs(shap)).replace("0.","")
    q = ''.join(random.choice(string.ascii_uppercase) for i in range(3))
    return q + k + "_" + term

# %%
def parseLine(df_result):
    factors = []
    ids = []
    for i in df_result.index:
        row = df_result.loc[i]
        shap = row['shap']
        term = row['term']
        occ = row['occurrence']
        factor = getFactor(shap, occ)
        identifier = createTermID(term, shap)
        factors.append(factor)
        ids.append(identifier)
    new = df_result.copy()
    new['factor'] = factors
    new['id'] = ids
    return new

# %%
def getJSON(df_og):
    result = "["
    df_result = parseLine(df_og)
    length = len(df_result.index)
    for i in df_result.index:
        row = df_result.loc[i].to_json()
        if (length == 1):
            result += row
        else:
            t = row + ","
            result += t
        length -= 1
    result += "]"
    return result

# %%
# LOOP
json_collection = []
result = file.copy()

for i in file.index:
    record = file.loc[i]
    p = predictRecord(record)
    sv = getSHAPValues(p)
    jayson = getJSON(sv)
    json_collection.append(jayson)
    
# append jayson to record
result['Shap_json'] = json_collection
result.index.name = "Iterator"
result.to_csv('fitbit_shap.csv', sep='\t')
result
# Out:
#                        Name                                             Title  \
# Iterator
# 0           Amazon Customer                              Not worth the hassle
# 1                    Aubrey                        Listen to the poor reviews
# 2           Amazon Customer                 It stopped working after 3 months
# 3                    Sophia                      scratched and not that great
# 4         Cassandra Reising                           All in all a good watch
# 5                  Gearhead                                Works as designed.
# 6                speedemonj                                 Great for fitness
# 7                     Tyler                           Good bang for your buck
# 8           Kindle Customer      HUGE improvement over the first Fitbit Versa
# 9            Nicole Quigley                                         Love It!!
# 10          Amazon Customer                                Versa 2 is amazing
# 11                      Hal                                   Simple and nice
# 12                  Heather                                   Great purchase!
# 13         jessica albrecht                               I LOVE THE VERSA 2.
# 14                   K Olds           Happy with the change to Fitbit Versa 2
# 15                  Nkie715                               This watch, bad app
# 16             Eileen Jones                  Quality product for a good price
# 17           Skye Musacchia                                           Amazing
# 18                  J. Wong      Sleep and weight tracking features are great
# 19            Phillip Ezell          Great capability for a reasonable price.
# 20                   Debbie                                        I love it!
# 21             Dreamersland                                  Love my Fitbit!!
# 22             Katzapainter  Lots of info on this watch and very light weight
# 23              Ashlyn Pond         Comfy and motivational! Highly recommend!
# 24          Sierra Wrathall                                       Best watch!
# 25             Taylor Meeks                             The Best FitBit Ever!
# 26                    Pappy                                    My New Fitbit.
# 27              Jill Fowler                               Happy with purchase
# 28                     BevD               Absolutely love the Fitbit Versa 2!
# 29               UberFoodie                                   Love this thing
#
#                                                      Review  Rating  \
# Iterator
# 0         The strap is really hard to change. I managed ...     1.0
# 1         I've used fitbit products for years. My well l...     1.0
# 2         My fitbit stopped working after 3 months. The ...     2.0
# 3         I have had this watch for less than a month an...     3.0
# 4         I have had this for about a month and am very ...     4.0
# 5         Bought this for my girlfriend. Thought I was t...     4.0
# 6         Great for fitness, sleep, etc but you have to ...     4.0
# 7         I had a Fitbit blaze before I got the versa 2 ...     4.0
# 8         My first Fitbit Versa was great and died 4 mon...     5.0
# 9         After buying a cheaper type of fitness tracker...     5.0
# 10        Amazing sleep tracking and great step and hear...     5.0
# 11        It’s pretty sleek. Sleep tracking doesn’t alwa...     5.0
# 12        Very impressed with the features and comfort o...     5.0
# 13        I love it! It's cute, comfortable, and works r...     5.0
# 14        LOVE my new Fitbit Versa 2 Easy to learn and v...     5.0
# 15        This watch is great, however, the Fitbit app k...     5.0
# 16        I bought this item fairly quickly and without ...     5.0
# 17        Absolutely love this watch!!!  I would highly ...     5.0
# 18        I am mainly writing a review of the sleep and ...     5.0
# 19        I like the fitness and sleep tracking capabili...     5.0
# 20        I love my Versa 2, but I can only compare it t...     5.0
# 21        Got it yesterday.  Super easy to set up, very ...     5.0
# 22        Love my Fitbit. Very light weight. Everything ...     5.0
# 23        I love my watch so much, and didn’t realize ho...     5.0
# 24        Amazing smart watch/ fitness tracker! Well wor...     5.0
# 25        What an awesome product!! I upgraded from the ...     5.0
# 26        I have had several different Fitbit watches ov...     5.0
# 27        Happy with purchase.  Love having the insight ...     5.0
# 28        I purchased the Fitbit Versa 2 and I love it. ...     5.0
# 29        I opted for this over an Apple Watch, because ...     5.0
#
#           Prediction                                          Shap_json
# Iterator
# 0           0.526897  [{"shap":-1.2216773556,"term":"attach","occurr...
# 1           0.687864  [{"shap":-1.0183404569,"term":"poor","occurren...
# 2           2.005359  [{"shap":1.2231704767,"term":"prompted","occur...
# 3           3.050132  [{"shap":1.3777308968,"term":"alta","occurrenc...
# 4           3.999938  [{"shap":0.4017336522,"term":"amazing","occurr...
# 5           4.057881  [{"shap":-0.4577140271,"term":"apps","occurren...
# 6           4.112775  [{"shap":0.31252238,"term":"great","occurrence...
# 7           4.344578  [{"shap":-1.0821097325,"term":"horrible","occu...
# 8           4.502670  [{"shap":0.7109636365,"term":"great","occurren...
# 9           4.955996  [{"shap":0.6609941128,"term":"motivates","occu...
# 10          4.512607  [{"shap":-0.7728642195,"term":"wayyyyy","occur...
# 11          5.020646  [{"shap":0.5241000091,"term":"nice","occurrenc...
# 12          5.031151  [{"shap":-0.5269183664,"term":"cheap","occurre...
# 13          5.043513  [{"shap":-0.6473751153,"term":"breathing","occ...
# 14          5.054810  [{"shap":0.821321159,"term":"love","occurrence...
# 15          5.055352  [{"shap":1.1802976366,"term":"uninstall","occu...
# 16          5.056388  [{"shap":0.3492499413,"term":"pleased","occurr...
# 17          5.058111  [{"shap":1.2766199952,"term":"love","occurrenc...
# 18          5.060681  [{"shap":-1.0441078378,"term":"graphical","occ...
# 19          5.075542  [{"shap":0.3445370308,"term":"capability","occ...
# 20          5.077276  [{"shap":-1.2569712069,"term":"lantern","occur...
# 21          5.079998  [{"shap":0.8836930402,"term":"fitbits","occurr...
# 22          5.112900  [{"shap":0.821321159,"term":"love","occurrence...
# 23          5.110651  [{"shap":0.4657401035,"term":"track","occurren...
# 24          5.084164  [{"shap":0.4017336522,"term":"amazing","occurr...
# 25          5.138477  [{"shap":-1.7686832933,"term":"fluent","occurr...
# 26          5.489931  [{"shap":0.3275928796,"term":"best","occurrenc...
# 27          5.402453  [{"shap":0.6609941128,"term":"motivates","occu...
# 28          5.206577  [{"shap":0.3986077035,"term":"fitbit","occurre...
# 29          5.170615  [{"shap":1.5078461495,"term":"great","occurren...
